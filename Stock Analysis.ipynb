# %%
from pandas_datareader import data as pdr
import datetime
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
import yfinance as yf

# %%
yf.pdr_override()

# %%
#pip install pandas-datareader

# %%
start = datetime.datetime(2012,1,1)
end = datetime.datetime(2017,1,1)

# %%
print(start)
# Out:
# 2012-01-01 00:00:00

# %%
#y_symbols = ['SCHAND.NS', 'TATAPOWER.NS', 'ITC.NS']

# %%
tesla = pdr.get_data_yahoo('TSLA', start=start, end=end)
ford = pdr.get_data_yahoo('F', start=start, end=end)
gm = pdr.get_data_yahoo('GM', start=start, end=end)
# Out:
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed

# %%
tesla.head()
# Out:
#                 Open      High       Low     Close  Adj Close    Volume
# Date
# 2012-01-03  1.929333  1.966667  1.843333  1.872000   1.872000  13921500
# 2012-01-04  1.880667  1.911333  1.833333  1.847333   1.847333   9451500
# 2012-01-05  1.850667  1.862000  1.790000  1.808000   1.808000  15082500
# 2012-01-06  1.813333  1.852667  1.760667  1.794000   1.794000  14794500
# 2012-01-09  1.800000  1.832667  1.741333  1.816667   1.816667  13455000

# %%
ford.head()
# Out:
#              Open   High    Low  Close  Adj Close    Volume
# Date
# 2012-01-03  11.00  11.25  10.99  11.13   6.681700  45709900
# 2012-01-04  11.15  11.53  11.07  11.30   6.783758  79725200
# 2012-01-05  11.33  11.63  11.24  11.59   6.957854  67877500
# 2012-01-06  11.74  11.80  11.52  11.71   7.029894  59840700
# 2012-01-09  11.83  11.95  11.70  11.80   7.083924  53981500

# %%
gm.head()
# Out:
#                  Open       High        Low      Close  Adj Close    Volume
# Date
# 2012-01-03  20.830000  21.180000  20.750000  21.049999  16.113821   9321300
# 2012-01-04  21.049999  21.370001  20.750000  21.150000  16.190365   7856700
# 2012-01-05  21.100000  22.290001  20.959999  22.170000  16.971174  17880600
# 2012-01-06  22.260000  23.030001  22.240000  22.920000  17.545301  18234500
# 2012-01-09  23.200001  23.430000  22.700001  22.840000  17.484062  12084500

# %%
tesla['Open'].plot(label='Tesla',figsize=(15,7))
gm['Open'].plot(label='GM')
ford['Open'].plot(label='Ford')
plt.ylabel('Stock Prices')
plt.title('Stock Prices of Tesla , GM and Ford')
plt.legend()

# %%
tesla['Volume'].plot(label='Tesla',figsize=(15,7))
gm['Volume'].plot(label='GM')
ford['Volume'].plot(label='Ford')
plt.ylabel('Volume Traded')
plt.title('Stock Prices of Tesla , GM and Ford')
plt.legend()
# https://money.cnn.com/2013/12/18/news/companies/ford-profit/index.html

# %%
ford.iloc[[ford['Volume'].argmax()]]
# Out:
#              Open  High    Low  Close  Adj Close     Volume
# Date
# 2013-12-18  15.99  16.0  15.17  15.65   9.824941  220363000

# %%
ford.iloc[420:520]['Open'].plot()
# when stocks drops volume goes up
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
# google['Open'].plot(label='Google Open Price',figsize = (15,7))
# google['Close'].plot(label='Google Close Price')
# google['High'].plot(label='Google Close Price')
# google['Low'].plot(label='Google Close Price')
# plt.title('Google Stock Prices')
# plt.ylabel('Stock Price')
# plt.legend()

# plt.show()

# %%
# Market Cap

# %%
tesla['Total Traded'] = tesla['Open'] * tesla['Volume']
gm['Total Traded'] = gm['Open'] * gm['Volume']
ford['Total Traded'] = ford['Open'] * ford['Volume']

# %%
tesla.head()
# Out:
#                 Open      High       Low     Close  Adj Close    Volume  \
# Date
# 2012-01-03  1.929333  1.966667  1.843333  1.872000   1.872000  13921500
# 2012-01-04  1.880667  1.911333  1.833333  1.847333   1.847333   9451500
# 2012-01-05  1.850667  1.862000  1.790000  1.808000   1.808000  15082500
# 2012-01-06  1.813333  1.852667  1.760667  1.794000   1.794000  14794500
# 2012-01-09  1.800000  1.832667  1.741333  1.816667   1.816667  13455000
#
#             Total Traded
# Date
# 2012-01-03  2.685921e+07
# 2012-01-04  1.777512e+07
# 2012-01-05  2.791269e+07
# 2012-01-06  2.682736e+07
# 2012-01-09  2.421900e+07

# %%
ford.head()
# Out:
#              Open   High    Low  Close  Adj Close    Volume  Total Traded
# Date
# 2012-01-03  11.00  11.25  10.99  11.13   6.681700  45709900  5.028089e+08
# 2012-01-04  11.15  11.53  11.07  11.30   6.783758  79725200  8.889359e+08
# 2012-01-05  11.33  11.63  11.24  11.59   6.957854  67877500  7.690521e+08
# 2012-01-06  11.74  11.80  11.52  11.71   7.029894  59840700  7.025298e+08
# 2012-01-09  11.83  11.95  11.70  11.80   7.083924  53981500  6.386011e+08

# %%
gm.head()
# Out:
#                  Open       High        Low      Close  Adj Close    Volume  \
# Date
# 2012-01-03  20.830000  21.180000  20.750000  21.049999  16.113821   9321300
# 2012-01-04  21.049999  21.370001  20.750000  21.150000  16.190365   7856700
# 2012-01-05  21.100000  22.290001  20.959999  22.170000  16.971174  17880600
# 2012-01-06  22.260000  23.030001  22.240000  22.920000  17.545301  18234500
# 2012-01-09  23.200001  23.430000  22.700001  22.840000  17.484062  12084500
#
#             Total Traded
# Date
# 2012-01-03  1.941627e+08
# 2012-01-04  1.653835e+08
# 2012-01-05  3.772807e+08
# 2012-01-06  4.059000e+08
# 2012-01-09  2.803604e+08

# %%
tesla['Total Traded'].plot(label='Tesla',figsize=(15,7))
gm['Total Traded'].plot(label='GM')
ford['Total Traded'].plot(label='Ford')
plt.legend()
plt.ylabel('Total Traded')
# Out:
# Text(0, 0.5, 'Total Traded')

# %%
tesla['Total Traded'].argmax()
# Out:
# 538

# %%
tesla.iloc[[tesla['Total Traded'].argmax()]]
# Out:
#                  Open       High    Low      Close  Adj Close     Volume  \
# Date
# 2014-02-25  15.333333  17.280001  15.23  16.533333  16.533333  490225500
#
#             Total Traded
# Date
# 2014-02-25  7.516791e+09

# %%
# https://money.cnn.com/2014/02/25/investing/tesla-record-high/

# %%
gm['Open'].plot(figsize=(15,7),label='No Moving Average')
gm['MA50'] = gm['Open'].rolling(50).mean()
gm['MA50'].plot(label='MA50')
gm['MA200'] = gm['Open'].rolling(200).mean()
gm['MA200'].plot(label='MA200')
plt.legend()

# %%
gm['Open'].iloc[440:500].plot(figsize=(15,7))
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
from pandas.plotting import scatter_matrix

# %%
import pandas as pd

# %%
car_comp = pd.concat([tesla['Open'],gm['Open'],ford['Open']],axis=1)
car_comp.columns = ['Tesla Open','GM Open','Ford Open']

# %%
scatter_matrix(car_comp,figsize=(8,8),hist_kwds={'bins':50})
# Out:
# array([[<AxesSubplot:xlabel='Tesla Open', ylabel='Tesla Open'>,
#         <AxesSubplot:xlabel='GM Open', ylabel='Tesla Open'>,
#         <AxesSubplot:xlabel='Ford Open', ylabel='Tesla Open'>],
#        [<AxesSubplot:xlabel='Tesla Open', ylabel='GM Open'>,
#         <AxesSubplot:xlabel='GM Open', ylabel='GM Open'>,
#         <AxesSubplot:xlabel='Ford Open', ylabel='GM Open'>],
#        [<AxesSubplot:xlabel='Tesla Open', ylabel='Ford Open'>,
#         <AxesSubplot:xlabel='GM Open', ylabel='Ford Open'>,
#         <AxesSubplot:xlabel='Ford Open', ylabel='Ford Open'>]],
#       dtype=object)

# %%
# Candel stick chart

# %%
#from mpl_finance import candlestick_ohlc

# %%
from mplfinance.original_flavor import candlestick_ohlc

# %%
#pip install mplfinance

# %%
from matplotlib.dates import DateFormatter , date2num , DayLocator , MONDAY

# %%
from matplotlib.dates import WeekdayLocator

# %%
ford_reset = ford.loc['2012-01':'2012-01'].reset_index()

# %%
ford_reset['date_ax'] = ford_reset['Date'].apply(lambda date:date2num(date))

# %%
ford_values = [tuple(vals) for vals in ford_reset[['date_ax','Open','High','Low','Close']].values]

# %%
mondays = WeekdayLocator(MONDAY)
alldays = DayLocator()
weekFormatter = DateFormatter('%b %d')
dayFormatter = DateFormatter('%d')

# %%
fig , ax = plt.subplots()
candlestick_ohlc(ax,ford_values,width=0.6,colorup='green',colordown='red')
# Out:
# ([<matplotlib.lines.Line2D at 0x1cc7dbb4190>,
# ...
#   <matplotlib.patches.Rectangle at 0x1cc7dcbaeb0>])

# %%
# Daily percentage change

# rt = pt/pt-1 - 1

# %%
# you bought some stock at t-1 and sold at t if t > t-1 then rt will be positive
# helpful to analyze daily valatility of stock

# %%
# find stable stock

# %%
tesla['returns'] = ((tesla['Close'] / tesla['Close'].shift(1)) - 1)

# %%
tesla.head()
# Out:
#                 Open      High       Low     Close  Adj Close    Volume  \
# Date
# 2012-01-03  1.929333  1.966667  1.843333  1.872000   1.872000  13921500
# 2012-01-04  1.880667  1.911333  1.833333  1.847333   1.847333   9451500
# 2012-01-05  1.850667  1.862000  1.790000  1.808000   1.808000  15082500
# 2012-01-06  1.813333  1.852667  1.760667  1.794000   1.794000  14794500
# 2012-01-09  1.800000  1.832667  1.741333  1.816667   1.816667  13455000
#
#             Total Traded   returns
# Date
# 2012-01-03  2.685921e+07       NaN
# 2012-01-04  1.777512e+07 -0.013177
# 2012-01-05  2.791269e+07 -0.021292
# 2012-01-06  2.682736e+07 -0.007743
# 2012-01-09  2.421900e+07  0.012635

# %%
ford['returns'] = ((ford['Close'] / ford['Close'].shift(1)) - 1)
gm['returns'] = ((gm['Close'] / gm['Close'].shift(1)) - 1)

# %%
ford.head()
# Out:
#              Open   High    Low  Close  Adj Close    Volume  Total Traded  \
# Date
# 2012-01-03  11.00  11.25  10.99  11.13   6.681700  45709900  5.028089e+08
# 2012-01-04  11.15  11.53  11.07  11.30   6.783758  79725200  8.889359e+08
# 2012-01-05  11.33  11.63  11.24  11.59   6.957854  67877500  7.690521e+08
# 2012-01-06  11.74  11.80  11.52  11.71   7.029894  59840700  7.025298e+08
# 2012-01-09  11.83  11.95  11.70  11.80   7.083924  53981500  6.386011e+08
#
#              returns
# Date
# 2012-01-03       NaN
# 2012-01-04  0.015274
# 2012-01-05  0.025664
# 2012-01-06  0.010354
# 2012-01-09  0.007686

# %%
gm.head()
# Out:
#                  Open       High        Low      Close  Adj Close    Volume  \
# Date
# 2012-01-03  20.830000  21.180000  20.750000  21.049999  16.113821   9321300
# 2012-01-04  21.049999  21.370001  20.750000  21.150000  16.190365   7856700
# 2012-01-05  21.100000  22.290001  20.959999  22.170000  16.971174  17880600
# 2012-01-06  22.260000  23.030001  22.240000  22.920000  17.545301  18234500
# 2012-01-09  23.200001  23.430000  22.700001  22.840000  17.484062  12084500
#
#             Total Traded  MA50  MA200   returns
# Date
# 2012-01-03  1.941627e+08   NaN    NaN       NaN
# 2012-01-04  1.653835e+08   NaN    NaN  0.004751
# 2012-01-05  3.772807e+08   NaN    NaN  0.048227
# 2012-01-06  4.059000e+08   NaN    NaN  0.033829
# 2012-01-09  2.803604e+08   NaN    NaN -0.003490

# %%
# Volatilty

# %%
ford['returns'].hist(bins=50)
# flatter the tail less varience , data is close to mean less std
# Out:
# <AxesSubplot:>

# %%
gm['returns'].hist(bins=50)
# Out:
# <AxesSubplot:>

# %%
tesla['returns'].hist(bins=50)
# Out:
# <AxesSubplot:>

# %%
tesla['returns'].hist(bins=100,label='Tesla',alpha=0.5,figsize=(13,5))
gm['returns'].hist(bins=100,label='GM',alpha=0.5)
ford['returns'].hist(bins=100,label='Ford',alpha=0.5)
plt.legend()

# %%
tesla['returns'].plot(kind='kde',label='Tesla',figsize=(17,6))
gm['returns'].plot(kind='kde',label='GM')
ford['returns'].plot(kind='kde',label='Ford')
plt.legend()

# %%
box_df = pd.concat([tesla['returns'],gm['returns'],ford['returns']],axis=1)

# %%
box_df.columns = ['Tesla Returns','GM Returns','Ford Returns']

# %%
box_df.boxplot(figsize=(16,6))
# Out:
# <AxesSubplot:>

# %%
#box_df['returns'] = pd.to_numeric(box_df['returns'])

# %%
scatter_matrix(box_df,figsize=(8,8),hist_kwds={'bins':50},alpha=0.25)
# Out:
# array([[<AxesSubplot:xlabel='Tesla Returns', ylabel='Tesla Returns'>,
#         <AxesSubplot:xlabel='GM Returns', ylabel='Tesla Returns'>,
#         <AxesSubplot:xlabel='Ford Returns', ylabel='Tesla Returns'>],
#        [<AxesSubplot:xlabel='Tesla Returns', ylabel='GM Returns'>,
#         <AxesSubplot:xlabel='GM Returns', ylabel='GM Returns'>,
#         <AxesSubplot:xlabel='Ford Returns', ylabel='GM Returns'>],
#        [<AxesSubplot:xlabel='Tesla Returns', ylabel='Ford Returns'>,
#         <AxesSubplot:xlabel='GM Returns', ylabel='Ford Returns'>,
#         <AxesSubplot:xlabel='Ford Returns', ylabel='Ford Returns'>]],
#       dtype=object)

# %%
# Cumulative Returns
# It help us if you invested certain amount at cetrain date what it will be that worth
# if you invested 1 dollar at company at start what it worth today

# %%
# it = (1 + rt)it - 1

# %%
tesla['Cumulative Returns'] = (1 + tesla['returns']).cumprod()

# %%
tesla.head()
# Out:
#                 Open      High       Low     Close  Adj Close    Volume  \
# Date
# 2012-01-03  1.929333  1.966667  1.843333  1.872000   1.872000  13921500
# 2012-01-04  1.880667  1.911333  1.833333  1.847333   1.847333   9451500
# 2012-01-05  1.850667  1.862000  1.790000  1.808000   1.808000  15082500
# 2012-01-06  1.813333  1.852667  1.760667  1.794000   1.794000  14794500
# 2012-01-09  1.800000  1.832667  1.741333  1.816667   1.816667  13455000
#
#             Total Traded   returns  Cumulative Returns
# Date
# 2012-01-03  2.685921e+07       NaN                 NaN
# 2012-01-04  1.777512e+07 -0.013177            0.986823
# 2012-01-05  2.791269e+07 -0.021292            0.965812
# 2012-01-06  2.682736e+07 -0.007743            0.958333
# 2012-01-09  2.421900e+07  0.012635            0.970442

# %%
ford['Cumulative Returns'] = (1 + ford['returns']).cumprod()
gm['Cumulative Returns'] = (1 + gm['returns']).cumprod()

# %%
tesla['Cumulative Returns'].plot(label='Tesla',figsize=(15,7))
ford['Cumulative Returns'].plot(label='ford')
gm['Cumulative Returns'].plot(label='gm')
plt.legend()
